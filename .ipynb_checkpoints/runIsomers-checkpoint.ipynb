# %%
import json as json
import matplotlib.pyplot as plt
import os
import numpy as np

import multifil
import treatment_definitions as td
import graphing_utilities as gutil

# List valid things that can be changed
print("valid constant (phenotype) parameters\n", multifil.hs.hs.VALID_PARAMS)
# Out:
# imported myosin multifil
# valid constant (phenotype) parameters
#  ['mf_k', 'mh_c_ks', 'mh_c_kw', 'mh_c_rs', 'mh_c_rw', 'mh_g_ks', 'mh_g_kw', 'mh_g_rs', 'mh_g_rw', 'detachment_rate', 'mh_fd_k0', 'mh_fd_delta', 'af_k', 'ti_a', 'ti_b']

# %%
# Setup experiment, show the traces
time_trace, length_trace, ap_trace, _ = td.t_spring()  # We only want the three traces

wildtype = False
if wildtype:
    # specify we want the force-sensitive detatchment rate
    comment = "WT"
    params = {'detachment_rate':'force_sensitive', 'mh_fd_k0':0.102, 'mh_fd_delta':1.3} # Wildtype
else:
    # Create mh isomer profile - D239N mechanics
    comment = "50:D239N;50:WT"
    params = {'mh_iso':[{'iso_p':0.5, 'detachment_rate':'force_sensitive', 'mh_fd_k0':0.102, 'mh_fd_delta':1.3},  # Wildtype
                        {'iso_p':0.5, 'detachment_rate':'force_sensitive', 'mh_fd_k0':0.140, 'mh_fd_delta':1.4}   # D239N
                       ]
             }

#plot the traces
gutil.plot_input_traces(time_trace, length_trace, ap_trace)

#print the phenotype settings

# %%
"""This code runs a single simulation"""
output_dir = "../_output/force_sensitive/"
os.makedirs(output_dir, exist_ok=True)

# check the comment to see what we are passing to it.
wl_meta = multifil.aws.metas.emit(
    path_local=output_dir,  # local dir to save run output to
    path_s3=None,  #s3 bucket to upload results to
    time=time_trace,
    poisson=0.0,  # poisson ratio, set to const lattice here
    ls=None,  # intial ls, using default by passing none
    z_line=length_trace, 
    actin_permissiveness=ap_trace,
    comment=comment,  # comment describing run
    hs_params=params,  # constants we want to alter - phenotype
    write=True,  # whether to write out resulting file or just pass back to variable
)

# determine where the metafile was saved.
run_name = wl_meta['name']
print(run_name)
run_file = output_dir + run_name + ".meta.json"

print(wl_meta['hs_params'])

run_manager = multifil.aws.run.manage(run_file, unattended=False) # have run.py create the sarc from meta
# Begin running
data, exit_code = run_manager.run_and_save()   # with our new sarc, run it, getting the data from it.
# Out:
# 78f94a80-69a8-11ea-b739-185680feb82e
# {'mh_iso': [{'iso_p': 0.5, 'detachment_rate': 'force_sensitive', 'mh_fd_k0': 0.102, 'mh_fd_delta': 1.3}, {'iso_p': 0.5, 'detachment_rate': 'force_sensitive', 'mh_fd_k0': 0.14, 'mh_fd_delta': 1.4}]}
#
# MainProcess finished timestep 1 of 1000, 0h2m43s left
# C:\Users\Anthony\Documents\github\fd_multifil\multifil\ti.py:184: UserWarning: Check radial force direction in titin
#   warnings.warn("Check radial force direction in titin")
# MainProcess finished timestep 101 of 1000, 0h5m18s left
# MainProcess finished timestep 201 of 1000, 0h6m2s left
# MainProcess finished timestep 301 of 1000, 0h5m26s left
# MainProcess finished timestep 401 of 1000, 0h4m40s left
# MainProcess finished timestep 501 of 1000, 0h3m46s left
# MainProcess finished timestep 601 of 1000, 0h2m58s left
# MainProcess finished timestep 701 of 1000, 0h2m8s left
# MainProcess finished timestep 801 of 1000, 0h1m22s left
# MainProcess finished timestep 901 of 1000, 0h0m39s leftrun.py MainProcess # ## model finished, uploading
# run.py MainProcess # ## uploading finished, done with this run

# %%
# graph the result
gutil.plot_data(data, title=comment, save_dir=output_dir)
# Out:
# saved to: ../_output/force_sensitive/\78f94a80-69a8-11ea-b739-185680feb82e.png

# %%
gutil.print_constants(data['constants'])
# Out:
# ti
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
#  	ti_a = 240 ti_b = 0.0045
# af
#  	af_k = 1743
#  	af_k = 1743
#  	af_k = 1743
#  	af_k = 1743
#  	af_k = 1743
#  	af_k = 1743
#  	af_k = 1743
#  	af_k = 1743
# mf
#  	mf_k = 2020
#  	mf_k = 2020
#  	mf_k = 2020
#  	mf_k = 2020
# mh
#  	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_ra ...
# 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102  ...
#  1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachm ...
#  19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.102 mh_fd_delta = 1.3 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_rs = 1.2775810124598492 mh_g_ks = 2 mh_g_kw = 2 mh_g_rw = 19.93 mh_g_rs = 16.47 detachment_rate = force_sensitive mh_fd_k0 = 0.14 mh_fd_delta = 1.4 , 	 	mh_c_ks = 40 mh_c_kw = 40 mh_c_rw = 0.8230972752405258 mh_c_ ...
